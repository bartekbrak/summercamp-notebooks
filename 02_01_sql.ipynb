# %% [markdown]
# # SQL as implemented in MySQL and Postgres; transaction handling and consistency; SQLAlchemy
#
#
# ### Robert
#
# Date: Tuesday, 7 June 2015, day 2nd.
# Duration: 3h45min
#
# ### Agenda:
#
# - 9:00 - 9:55
# - 10:00 - 11:00
# - 11:10 - 12:00
# - 12:00 - 12:45
#
# ### Objectives:
# - refresh knowledge about SQL databases and their theory
# - take a look at PostgreSQL vs MySQL details
# - get to know how we use SQL databases at company
# - refresh Pythonic SQL skills
#
# ###URLs:
# - https://readthedocs.org/projects/python/ - offical documentation
# - https://github.com/kennethreitz/requests - that one useful github library thta makes everything easier
# - http://functionaltalks.org/2013/08/26/john-carmack-thoughts-on-haskell/ - this guy writes a lot about the subject

# %% [markdown]
# - idea SQL, dlaczego są noSQL
#     - kto zdefiniowal standard
#     - rola Oracle, co negatywnego, co dobrego
#     - wymienić
#     - historia MySQL, historia Postgresa
#     - forki / varianty: mariaDB
#     - WI: dlaczego mamy MySQL, czy żałujemy, dlaczego mamy Postgres, jaka przyszłość
#     - lista innych baz, szczególnie SQLite
#     - replication patters: master<>master, master<>slave, binlog
#     -
#
# - Python db usage
#     - dbapi: ex('simple query')
#     - orms:
#         - sqlalchemy, django,
#         - sample code in alchemy and django,
#         - why do we use them, whatare the pitfalls?
#         - entities: models, queries, queryset...
#     - transactional code general pattern, what it looks like in Python
#     - SQL Injection, escaping, mother bad example, mother good example
#
# - QUERY exercices
#     - JOIN, INNER LEFT
#     - GROUP BY
#     - aggregate: AVG, MAX, MIN
#     - DISTINCT
#     - SUBQUERIES
#
# - Transactions, consistency, theory
#     - theory
#         - ACID, show ACID compliance numbers
#         - CAP theorem, ACID ipossible on network partition (mention split brain)
#     - transaction is no silver bullet
#     - mention that you can completely lose the gain of transactions when you spread across microservices
#     - general patterns of transaction-like behaviour in distributed systems
#     - zope
#
# - Postgres v MySQL
#     - transakcje: MVCC v lock_all
#     - storage on disk, how does this affect ALTERs
#     - how to access postgres (sudo su -; su postgres)
#     - where config files are /etc/my.cnf, /etc/postgres
#     - query planner, the benefit of the postgres one
#     - master slave
#     - ex1: konwersja P->M, M->P
#     - percona, inne komerc. narzędzia do Post i My
#
#
# - SQLALchemy
#     - set-up, dbsession etc
#     - column types
#     - constraints, indices,
#     - declarative vs automapper base
#     - queries, filters, aggregations, specifying columns, raw, fetchone, fetchall, query args,
#     - relations: O2M, M2M
#     - objects lifecycle: create, add, save, flush, what is session?
#     - ex1: create model, (extract schema to simple SQL file), user database, add/remove/update user

# %% [markdown]
# # Conclusion
#
# If you were two rememeber one thing it would be this: never emacs via sendmail.
#
# Brief recap of what we did:
# - thing one
# - thing two
# - thing three
#
# ### More useful stuff:
#
# - [Python C API](http://docs.python.org/2/c-api/): Python is implemented in C, and you can actually write C code which will compile to a Python module!  This is extremely low-level, and I would only recommend it if you enjoy pain (see Dan Foreman-Mackie's [blog post](http://dan.iel.fm/posts/python-c-extensions/) for a concise-as-possible introduction)
# - [SWIG](http://www.swig.org/): the Simplified Wrapper Interface Generator, can generate wrappers from a variety of low-level languages to a variety of high-level languages.  It's used heavily by LSST and other projects.
# - [Weave](http://docs.scipy.org/doc/scipy/reference/tutorial/weave.html): included in SciPy, weave is a method of putting C snippets within a Python program.  It's largely been superseded by Cython in practice.
# - [PyPy](http://pypy.org/): a JIT compiler for Python written in Python.  PyPy doesn't support the C backend which most scientific tools rely on, so it's not extremely useful for scientific computing.
